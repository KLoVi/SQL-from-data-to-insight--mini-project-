# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_1 = "Views/amount_products_per_gender.csv"

# %%
df_1 = pd.read_csv(csv_1)

# %%
df_1
# Out:
#              product_line    male  female
# 0      Food and beverages  22,974  33,171
# 1       Health and beauty  30,633  18,561
# 2       Sports and travel  26,548  28,575
# 3     Fashion accessories  23,868  30,437
# 4      Home and lifestyle  23,825  30,037
# 5  Electronic accessories  27,236  27,102

# %%
# Step 1: Create a DataFrame
data = {
    'product_line': ['Food and beverages', 'Health and beauty', 'Sports and travel', 'Fashion accessories', 'Home and lifestyle', 'Electronic accessories'],
    'male': [22974, 30633, 26548, 23868, 23825, 27236],
    'female': [33171, 18561, 28575, 30437, 30037, 27102]
}

df = pd.DataFrame(data)

# Step 2: Set the product_line as the index
df.set_index('product_line', inplace=True)

# Step 3: Plot the data
ax = df.plot(kind='bar', figsize=(8, 6), width=0.8)
plt.title('Sales by Product Line and Gender')
plt.xlabel('Product Line')
plt.ylabel('Amount of Sales (money)')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
csv_2 = "Views/amount_products_per_time.csv"

# %%
df_2 = pd.read_csv(csv_2)

# %%
df_2
# Out:
#            range_time food_beverages health_beauty sports_travel  \
# 0          01_morning         11,261         8,324         9,187
# 1           02_midday          8,059        10,224        12,262
# 2  03_early_afternoon         11,681        10,875        10,756
# 3   04_late_afternoon          5,984         6,697         9,003
# 4          05_evening         19,160        13,074        13,913
#
#   fashion_accessories home_lifestyle electronic_accesories
# 0              10,471         12,388                10,168
# 1              13,060          9,864                 7,320
# 2               8,202          9,043                11,450
# 3               9,664         10,745                 7,578
# 4              12,909         11,822                17,821

# %%
# df_2.set_index("range_time")

# %%
# Step 1: Create a DataFrame
data = {
    'range_time': ['morning', 'midday', 'early_afternoon', 'late_afternoon', 'evening'],
    'food_beverages': [11261, 8059, 11681, 5984, 19160],
    'health_beauty': [8324, 10224, 10875, 6697, 13074],
    'sports_travel': [9187, 12262, 10756, 9003, 13913],
    'fashion_accessories': [10471, 13060, 8202, 9664, 12909],
    'home_lifestyle': [12388, 9864, 9043, 10745, 11822],
    'electronic_accesories': [10168, 7320, 11450, 7578, 17821]
}

df = pd.DataFrame(data)

# Step 2: Set the range_time as the index
df.set_index('range_time', inplace=True)

# Step 3: Plot the heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(df, fmt='d', cmap='YlGnBu', linewidths=.5)
plt.title('Sales Distribution by Time Range and Product Line')
plt.xlabel('Product Line')
plt.ylabel('Time Range')
plt.xticks(rotation=45)
plt.yticks(rotation=0)

# Show the plot
plt.tight_layout()
plt.show()

# %%
csv_3 = "Views/amount_time_per_gender.csv"

# %%
df_3 = pd.read_csv(csv_3)

# %%
df_3
# Out:
#            range_time    male  female
# 0          01_morning  27,643  34,156
# 1           02_midday  24,105  36,684
# 2  03_early_afternoon  33,738  28,270
# 3   04_late_afternoon  23,328  26,343
# 4          05_evening  46,269  42,430

# %%
# Step 1: Create a DataFrame
data = {
    'range_time': ['morning', 'midday', 'early_afternoon', 'late_afternoon', 'evening'],
    'male': [27643, 24105, 33738, 23328, 46269],
    'female': [34156, 36684, 28270, 26343, 42430]
}

df = pd.DataFrame(data)

# Step 2: Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Define the bar width. Adjust as necessary.
bar_width = 0.35

# Plot male data
ax.bar(df['range_time'], df['male'], width=bar_width, label='Male', align='center')

# Plot female data with an offset to the right
#ax.bar(df['range_time'], df['female'], width=bar_width, label='Female', align='edge', bottom=0.4)

# Set the position of the bars on the x-axis
#r1 = np.arange(len(df['range_time']))  # Range for male bars
r2 = [x + bar_width for x in r1]       # Range for female bars

# Plot male and female bars
#ax.bar(r1, df['male'], width=bar_width,  label='Male')
ax.bar(r2, df['female'], width=bar_width,  label='Female')


# Customize the plot
plt.title('Sales by Time Range and Gender')
plt.xlabel('Time Range')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
csv_4 = "Views/qty_time_per_gender.csv"

# %%
df_4 = pd.read_csv(csv_4)

# %%
df_4
# Out:
#            range_time  male  female
# 0          01_morning    82     109
# 1           02_midday    85     107
# 2  03_early_afternoon   104      81
# 3   04_late_afternoon    77      74
# 4          05_evening   151     130

# %%
# Step 1: Create a DataFrame
data = {
    'range_time': ['morning', 'midday', 'early_afternoon', 'late_afternoon', 'evening'],
    'male': [82, 85, 104, 77, 151],
    'female': [109, 107, 81, 74, 130]
}

df = pd.DataFrame(data)

# Step 2: Plot the data
fig, ax = plt.subplots(figsize=(8, 6))

# Define the bar width and positions
bar_width = 0.3
index = np.arange(len(df['range_time']))

# Plot male data
ax.bar(index, df['male'], bar_width, label='Male')

# Plot female data with an offset to the right
ax.bar(index + bar_width, df['female'], bar_width, label='Female')

# Customize the plot
ax.set_xlabel('Time Range')
ax.set_ylabel('No of clients ')
ax.set_title('Amount of clients buying sth by Gender & Time Range')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(df['range_time'], rotation=45)
ax.legend(title='Gender')
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
